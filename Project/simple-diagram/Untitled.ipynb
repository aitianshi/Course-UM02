# %%
import pandas as pd

# %%
df = pd.read_csv("../beijing-pricing.csv", index_col="id")
df.head()
# Out:
#                                                             url         Lng  \
# id
# 101084782030  https://bj.lianjia.com/chengjiao/101084782030....  116.475489
# 101086012217  https://bj.lianjia.com/chengjiao/101086012217....  116.453917
# 101086041636  https://bj.lianjia.com/chengjiao/101086041636....  116.561978
# 101086406841  https://bj.lianjia.com/chengjiao/101086406841....  116.438010
# 101086920653  https://bj.lianjia.com/chengjiao/101086920653....  116.428392
#
#                     Lat            Cid   tradeTime     DOM  followers  \
# id
# 101084782030  40.019520  1111027376244  2016-08-09  1464.0        106
# 101086012217  39.881534  1111027381879  2016-07-28   903.0        126
# 101086041636  39.877145  1111040862969  2016-12-11  1271.0         48
# 101086406841  40.076114  1111043185817  2016-09-30   965.0        138
# 101086920653  39.886229  1111027381174  2016-08-28   927.0        286
#
#               totalPrice  price  square  ... buildingType constructionTime  \
# ...

# %%
list(df.columns)
# Out:
# ['url',
#  'id',
#  'Lng',
#  'Lat',
#  'Cid',
#  'tradeTime',
#  'DOM',
#  'followers',
#  'totalPrice',
#  'price',
#  'square',
#  'livingRoom',
#  'drawingRoom',
#  'kitchen',
#  'bathRoom',
#  'floor',
#  'buildingType',
#  'constructionTime',
#  'renovationCondition',
#  'buildingStructure',
#  'ladderRatio',
#  'elevator',
#  'fiveYearsProperty',
#  'subway',
#  'district',
#  'communityAverage']

# %%
df.district.unique()
# Out:
# array([ 7,  6,  1, 13, 10,  2,  8,  4,  5,  3,  9, 12, 11])
